# %% [markdown]
# # Gaussian process with Spike and Slab ARD prior - Stage 1 GP experiment
# ## Zero-temperature-pruning VI algorithm (continuous spike) - non additive kernels

# %% [markdown]
# ### (1) Importing and defining all required functions

# %%
"""
Importing in libraries for SGD-SS-GP
"""
# Requirements for algorithms
import numpy as np
import scipy.special as sp
from functools import partial
from scipy.spatial.distance import cdist

# Requirements for simulations/monitoring algorithms
import time
from IPython.display import clear_output
import inspect
from sklearn.metrics import roc_auc_score

# Requirements For plots and diagnostics
import matplotlib.pyplot as plt
import scipy.stats as sps
from mpl_toolkits import mplot3d

# Make plots inline
# %matplotlib inline

"""
Importing algorithm functions
"""
import os
os.chdir('C:/Users/hughw/Documents/MSC project/GP algorithms/Master function files')
from GP_funcs_ZTMFSS import kernel_funcs
from GP_funcs_ZTMFSS import model_funcs
from GP_funcs_ZTMFSS import draw_GP
from GP_funcs_ZTMFSS import fit
from GP_funcs_ZTMFSS import diagnostics
from GP_funcs_ZTMFSS import simulations
from functools import partial
os.chdir('C:/Users/hughw/Documents/MSC project/Simulation results')

# %% [markdown]
# ### (2) Setting simulation parameters and models

# %%
"""
Simulation controls
"""
# Simulation settings
n=300
ntest=100
p=100
q=5
corr=0.5 # used for GP draw
r2=2/3 # used for GP draw
lsmean=0.25
sigma2=1
ltrue=np.ones(p)*lsmean/q**0.5
strue=1

nruns = 100


# Model run settings
nmodels = 1
VS_threshs = [[0.01,0.05,0.1,0.2],
              [0.5,0.9,0.95,0.99],
             [0.5,0.9,0.95,0.99],
             [0.5,0.9,0.95,0.99],
             [0.5,0.9,0.95,0.99],
             [0.5,0.9,0.95,0.99],
             [0.5,0.9,0.95,0.99]]
iter_remove = [False, True,True,True,True, True, True]
sampling_strat = ["unif","unif", "unif", "unif", "unif", "unif", "unif"]
minibatch_size = [n,75, 75,150,150,n,n]
GPtol=[1e-6, 1e-5,1e-5,1e-5,1e-5,1e-5,1e-5]
SS_GP=[False, True,True,True,True,True,True]
MC_pred = [False,False,False,False,False,False,False]
predict_selected = [False,False,False,False,False,False,False]
post_fit = [False,False,False,False,False,False,False]
train = [True,True,False,True, False, True,False] 
step = [0.01,0.025,0.025,0.025,0.025,0.0025,0.0025]
hyper_opt = [False,True,True,True,True,True,True]
model_select = [True,False,True,False,True,False,True]
post_var = [False,True,True,True,True,True,True]
model_weights = ["","elpd", "elpd","elpd", "elpd","elpd", "elpd"]
min_VBEM_iter = [1,5,5,5,5,5,5]
max_VBEM_iter = [1,10,10,10,10,10,10]
gp_iter = [500,100,100,100,100,100,100]
X_mult = [1,1,1,1,1,10,10]
opt = ["adam", "amsgrad", "amsgrad", "amsgrad", "amsgrad", "amsgrad", "amsgrad"]
l_init = 0.01
beta2=0.99
t = len(VS_threshs[0])
kern=kernel_funcs.gaussian
grad_kern=kernel_funcs.grad_gaussian
reg = 0.01
NN_pred = False
newsumgrads = False
VBtol=0.1/p
temp=1
v0=1e+4
v1=1e-4
postfit = "mixed"
# SEE BELOW FOR ARGVALS

# Storage objects
m=nmodels
Runtime=np.zeros((nruns, m))
Lambda = np.zeros((nruns, m, p))
L = np.zeros((nruns, m, p))
L1norm=np.zeros((nruns, m))
L2norm=np.zeros((nruns, m))
MSE_F=np.zeros((nruns, m))
MSE_Y=np.zeros((nruns,m))
Acc=np.zeros((nruns,m,t))
Weighted_Acc=np.zeros((nruns,m,t))
TPR=np.zeros((nruns,m,t))
TNR=np.zeros((nruns,m,t))
PPV=np.zeros((nruns,m,t))
NPV=np.zeros((nruns,m,t))
AUC=np.zeros((nruns,m))
MCC=np.zeros((nruns,m,t))

# %% [markdown]
# ### (3) Drawing synthetic data, running algorithm, and displaying results

# %%
np.random.seed(8750)
runlist = np.random.choice(1000,nruns,False) # Choose 100 random trials
for run in range(len(runlist)):
    
    """
    Generating data and scaling data
    """
    lselect=[]
    np.random.seed(runlist[run]) # Fixing trial seed
    t=time.time()
    Y,F,X,e,lselect,strue,sigma,select=draw_GP.draw_GP_ARD_lm(n,ntest,p,q,sigma2,corr,strue,ltrue,plot_YX=True,kern=kern,cop=False,r2=r2)
    
    Y = Y.reshape(n+ntest,1)
    F = F.reshape(n+ntest,1)
    
    Y = (Y-Y[:n].mean())/Y[:n].var()**0.5
    X = (X-X[:n].mean(0))/X[:n].var(0)**0.5
    F = (F-F[:n].mean())/F[:n].var()**0.5

    # Getting training and test set
    ytest=Y[n:]
    Xtest=X[n:]
    ftest=F[n:]
    y=Y[:n]
    X=X[:n]
    f=F[:n]
    print("data generated")
    if lselect.any():
        print("Length-scales are: ",lselect[select])
    print("Noise variance is: ",sigma**2)
    print("Average data variance is: ", np.mean(np.var(X,0)))
    print("Time taken to draw data : ", time.time()-t)
    
    """
    Running algorithm
    """
    args = []
    arg_vals = []
    for i in range(nmodels):
        args.append(["seed","subsample", "sampling_strat", "min_VBEM_iter", "max_VBEM_iter", "GP_fit_tol", "VBEM_tol", "max_GP_fit_iter", "init_GP_iter", "iter_remove", "print_VBEM", "learn_rate", "optimisation", "X_mult"])
        arg_vals.append([0,minibatch_size[i], sampling_strat[i], min_VBEM_iter[i], max_VBEM_iter[i], GPtol[i], 0.1/p, gp_iter[i],gp_iter[i], iter_remove[i], False, step[i], opt[i], X_mult[i]])

    test_algorithm = partial(diagnostics.get_pred_posterior_GP,reg = reg,kern = kernel_funcs.gaussian)

    Runtime[run], Lambda[run], L[run], L1norm[run], L2norm[run], MSE_F[run], MSE_Y[run], Acc[run], Weighted_Acc[run], TPR[run], TNR[run], PPV[run], NPV[run], AUC[run], MCC[run]= simulations.do_simulation_VBEMSSGP(
                               y, X, ftest, ytest, Xtest, q, algorithm_training = fit.VB_EM_GP_SS, algorithm_testing = test_algorithm, 
                               nmodels = m, args = args, arg_vals = arg_vals, post_fit = post_fit, SS_GP = SS_GP, post_var = post_var,
                               order_relevant_vars = False, order_irrelevant_vars = False, VS_threshs = VS_threshs, 
                               select = select, predict_selected = predict_selected, hyper_opt = hyper_opt, hyper_arg = ["v0","v1"],
                                hyper_vals = [1e+4*2**np.linspace(np.log2(100),-np.log2(100),11),1e-4*2**np.linspace(np.log2(100),-np.log2(100),11)], ltrue=lselect, MC_pred = MC_pred, model_select = model_select, post_fit_subsample=n, train = train,
                                model_weighting = model_weights)
    
    print("RUN {0}".format(run))
    print("Runtime mean is:", Runtime[:run+1].mean(0))
    print("Weighted accuracy mean is:", Weighted_Acc[:run].mean(0))
    print("TPR mean is:", TPR[:run+1].mean(0))
    print("PPV mean is:", PPV[:run+1].mean(0))
    print("MCC mean is:", MCC[:run+1].mean(0))
    print("L1norm mean is:", L1norm[:run+1].mean(0))
    print("L2norm mean is:", L2norm[:run+1].mean(0))
    print("MSE_F mean is:", MSE_F[:run+1].mean(0))
    print("MSE_Y mean is:", MSE_Y[:run+1].mean(0), "\n")
# Out:
# R2= 0.6650981093248958
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.027304068902007185
# Average data variance is:  1.0
# Time taken to draw data :  0.03789377212524414
# run time is : 40.623807191848755
# RUN 0
# Runtime mean is: [40.63793755]
# Weighted accuracy mean is: [[nan nan nan nan]]
# TPR mean is: [[1.  1.  0.8 0. ]]
# PPV mean is: [[0.17241379 0.45454545 0.57142857 0.        ]]
# MCC mean is: [[ 0.35896605  0.65256212  0.65638034 -0.02305715]]
# L1norm mean is: [1.51441338]
# L2norm mean is: [0.43852963]
# MSE_F mean is: [0.34777799]
# MSE_Y mean is: [0.51430425]
#
# R2= 0.6721101071837331
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.025248529499040346
# Average data variance is:  1.0000000000000002
# Time taken to draw data :  0.03383898735046387
# <ipython-input-50-4643903a10de>:55: RuntimeWarning: Mean of empty slice.
#   print("Weighted accuracy mean is:", Weighted_Acc[:run].mean(0))
# C:\Users\hughw\anaconda3\lib\site-packages\numpy\core\_methods.py:153: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# run time is : 26.25614047050476
# RUN 1
# Runtime mean is: [33.45443285]
# Weighted accuracy mean is: [[0.87368421 0.96842105 0.88421053 0.49473684]]
# TPR mean is: [[1.  1.  0.7 0.2]]
# PPV mean is: [[0.17241379 0.64393939 0.78571429 0.5       ]]
# MCC mean is: [[0.35896605 0.78030788 0.71147494 0.29982135]]
# L1norm mean is: [1.33954773]
# L2norm mean is: [0.37400693]
# MSE_F mean is: [0.237427]
# MSE_Y mean is: [0.41400265]
#
# R2= 0.6870532017129913
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.0243844951917865
# Average data variance is:  1.0
# Time taken to draw data :  0.03289389610290527
# run time is : 40.37881541252136
# RUN 2
# Runtime mean is: [35.76754681]
# Weighted accuracy mean is: [[0.87368421 0.98157895 0.84210526 0.59736842]]
# TPR mean is: [[1.         1.         0.73333333 0.2       ]]
# PPV mean is: [[0.15197957 0.51701223 0.64502165 0.5       ]]
# MCC mean is: [[0.32385358 0.67809999 0.64295628 0.29820193]]
# L1norm mean is: [1.86521994]
# L2norm mean is: [0.44993154]
# MSE_F mean is: [0.3257814]
# MSE_Y mean is: [0.50363131]
#
# R2= 0.6604472106556588
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.039159925188507826
# Average data variance is:  1.0
# Time taken to draw data :  0.03390955924987793
# run time is : 21.53831171989441
# RUN 3
# Runtime mean is: [32.21399015]
# Weighted accuracy mean is: [[0.84561404 0.96315789 0.84912281 0.59649123]]
# TPR mean is: [[0.95 0.9  0.65 0.15]]
# PPV mean is: [[0.14176245 0.4413306  0.54626623 0.375     ]]
# MCC mean is: [[0.29546462 0.58460898 0.54986822 0.21194412]]
# L1norm mean is: [2.21043174]
# L2norm mean is: [0.56690208]
# MSE_F mean is: [0.32103668]
# MSE_Y mean is: [0.4905732]
#
# R2= 0.641220740221536
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.005716827307339758
# Average data variance is:  1.0
# Time taken to draw data :  0.030393123626708984
# run time is : 40.554086208343506
# RUN 4
# Runtime mean is: [33.88501368]
# Weighted accuracy mean is: [[0.81710526 0.90789474 0.80394737 0.56710526]]
# TPR mean is: [[0.96 0.92 0.64 0.2 ]]
# PPV mean is: [[0.14912425 0.46417559 0.58701299 0.5       ]]
# MCC mean is: [[0.30994842 0.6135863  0.57101659 0.29409527]]
# L1norm mean is: [2.01681845]
# L2norm mean is: [0.51392828]
# MSE_F mean is: [0.3195567]
# MSE_Y mean is: [0.49755534]
#
# R2= 0.6702337075166944
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.036498742007834026
# Average data variance is:  1.0
# Time taken to draw data :  0.032332658767700195
# run time is : 26.574156999588013
# RUN 5
# Runtime mean is: [32.66908642]
# Weighted accuracy mean is: [[0.82947368 0.92210526 0.80210526 0.59368421]]
# TPR mean is: [[0.93333333 0.9        0.63333333 0.23333333]]
# PPV mean is: [[0.14510354 0.45347966 0.61417749 0.52777778]]
# MCC mean is: [[0.29763482 0.60053914 0.5851155  0.32801235]]
# L1norm mean is: [1.94850697]
# L2norm mean is: [0.49199531]
# MSE_F mean is: [0.3173607]
# MSE_Y mean is: [0.4797503]
#
# R2= 0.6339332185730303
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.02755191969077674
# Average data variance is:  1.0
# Time taken to draw data :  0.03135371208190918
# run time is : 40.830403327941895
# RUN 6
# Runtime mean is: [33.83713688]
# Weighted accuracy mean is: [[0.81666667 0.91315789 0.80087719 0.61052632]]
# TPR mean is: [[0.94285714 0.91428571 0.6        0.25714286]]
# PPV mean is: [[0.14421573 0.42837939 0.56215213 0.54761905]]
# MCC mean is: [[0.2988138  0.58469914 0.54018529 0.35223884]]
# L1norm mean is: [2.01691002]
# L2norm mean is: [0.50057122]
# MSE_F mean is: [0.32102963]
# MSE_Y mean is: [0.47722464]
#
# R2= 0.6866358915617431
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.009759434735306083
# Average data variance is:  0.9999999999999999
# Time taken to draw data :  0.03186988830566406
# run time is : 26.619633674621582
# RUN 7
# Runtime mean is: [32.93678427]
# Weighted accuracy mean is: [[0.81954887 0.91578947 0.78195489 0.62255639]]
# TPR mean is: [[0.95  0.9   0.625 0.3  ]]
# PPV mean is: [[0.14143267 0.40608197 0.55438312 0.60416667]]
# MCC mean is: [[0.29586277 0.56167437 0.54876952 0.40403018]]
# L1norm mean is: [2.04658885]
# L2norm mean is: [0.49234374]
# MSE_F mean is: [0.32159654]
# MSE_Y mean is: [0.47445088]
#
# R2= 0.6833412983059594
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.038329951924624295
# Average data variance is:  1.0
# Time taken to draw data :  0.031324148178100586
# run time is : 30.53675365447998
# RUN 8
# Runtime mean is: [32.67187023]
# Weighted accuracy mean is: [[0.81842105 0.90592105 0.79407895 0.64473684]]
# TPR mean is: [[0.95555556 0.91111111 0.66666667 0.33333333]]
# PPV mean is: [[0.14629406 0.39799878 0.56222944 0.64814815]]
# MCC mean is: [[0.30490324 0.55994596 0.57423808 0.44431233]]
# L1norm mean is: [2.01230581]
# L2norm mean is: [0.48510682]
# MSE_F mean is: [0.31994002]
# MSE_Y mean is: [0.46857396]
#
# R2= 0.6617437907552408
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.035036544249469115
# Average data variance is:  1.0
# Time taken to draw data :  0.03148794174194336
# run time is : 27.28476595878601
# RUN 9
# Runtime mean is: [32.13473644]
# Weighted accuracy mean is: [[0.82573099 0.91052632 0.81520468 0.6619883 ]]
# TPR mean is: [[0.94 0.88 0.66 0.32]]
# PPV mean is: [[0.14247546 0.37486557 0.53100649 0.60833333]]
# MCC mean is: [[0.29484537 0.52903147 0.55070122 0.41861281]]
# L1norm mean is: [2.09818469]
# L2norm mean is: [0.50020786]
# MSE_F mean is: [0.32537043]
# MSE_Y mean is: [0.47471788]
#
# R2= 0.6815709344560443
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.02046757683376572
# Average data variance is:  1.0000000000000002
# Time taken to draw data :  0.03106856346130371
# run time is : 21.910130262374878
# RUN 10
# Runtime mean is: [31.20676812]
# Weighted accuracy mean is: [[0.81578947 0.89157895 0.80894737 0.65421053]]
# TPR mean is: [[0.92727273 0.85454545 0.65454545 0.32727273]]
# PPV mean is: [[0.13861406 0.35019127 0.50091499 0.58333333]]
# MCC mean is: [[0.28507008 0.49518603 0.52692126 0.41041573]]
# L1norm mean is: [2.307292]
# L2norm mean is: [0.53683188]
# MSE_F mean is: [0.33552387]
# MSE_Y mean is: [0.47954858]
#
# R2= 0.6738376559404949
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.019741235095657714
# Average data variance is:  1.0
# Time taken to draw data :  0.03277397155761719
# run time is : 27.420780420303345
# RUN 11
# Runtime mean is: [30.89256366]
# Weighted accuracy mean is: [[0.8062201  0.8708134  0.80239234 0.65645933]]
# TPR mean is: [[0.93333333 0.86666667 0.68333333 0.33333333]]
# PPV mean is: [[0.14095178 0.373092   0.51869589 0.59027778]]
# MCC mean is: [[0.29051743 0.51875274 0.55269537 0.4176809 ]]
# L1norm mean is: [2.2185826]
# L2norm mean is: [0.51856533]
# MSE_F mean is: [0.32339572]
# MSE_Y mean is: [0.47154597]
#
# R2= 0.6840008003571818
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.024494122233946133
# Average data variance is:  1.0
# Time taken to draw data :  0.032450199127197266
# run time is : 41.81814742088318
# RUN 12
# Runtime mean is: [31.73414395]
# Weighted accuracy mean is: [[0.81140351 0.88026316 0.81798246 0.65964912]]
# TPR mean is: [[0.93846154 0.87692308 0.70769231 0.32307692]]
# PPV mean is: [[0.14176434 0.38712766 0.54289877 0.62179487]]
# MCC mean is: [[0.29331544 0.53496373 0.58003062 0.41925051]]
# L1norm mean is: [2.13990932]
# L2norm mean is: [0.49736781]
# MSE_F mean is: [0.31814678]
# MSE_Y mean is: [0.47018411]
#
# R2= 0.6729103731797128
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.008714576961873494
# Average data variance is:  1.0
# Time taken to draw data :  0.033234596252441406
# run time is : 27.08644962310791
# RUN 13
# Runtime mean is: [31.40323218]
# Weighted accuracy mean is: [[0.8145749  0.88785425 0.83157895 0.65506073]]
# TPR mean is: [[0.94285714 0.88571429 0.72857143 0.34285714]]
# PPV mean is: [[0.14214252 0.37827268 0.53658782 0.6202381 ]]
# MCC mean is: [[0.29519548 0.53058662 0.58521144 0.43065743]]
# L1norm mean is: [2.17049892]
# L2norm mean is: [0.5021886]
# MSE_F mean is: [0.3211769]
# MSE_Y mean is: [0.47249113]
#
# R2= 0.6439843244531762
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.026998243091711536
# Average data variance is:  0.9999999999999999
# Time taken to draw data :  0.03249239921569824
# run time is : 42.58112168312073
# RUN 14
# Runtime mean is: [32.14948866]
# Weighted accuracy mean is: [[0.81691729 0.8906015  0.84135338 0.66466165]]
# TPR mean is: [[0.94666667 0.89333333 0.72       0.32      ]]
# PPV mean is: [[0.14167536 0.37157302 0.5208153  0.57888889]]
# MCC mean is: [[0.29547306 0.52785812 0.57168798 0.39976202]]
# L1norm mean is: [2.18168812]
# L2norm mean is: [0.50608212]
# MSE_F mean is: [0.32724864]
# MSE_Y mean is: [0.47553439]
#
# R2= 0.6763146206856755
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.016104994249217856
# Average data variance is:  1.0
# Time taken to draw data :  0.03155517578125
# run time is : 27.572014570236206
# RUN 15
# Runtime mean is: [31.86434446]
# Weighted accuracy mean is: [[0.81789474 0.89333333 0.83614035 0.65298246]]
# TPR mean is: [[0.9375 0.8875 0.7125 0.3375]]
# PPV mean is: [[0.14017359 0.35971334 0.51505005 0.60520833]]
# MCC mean is: [[0.29092953 0.51494277 0.56574187 0.42268749]]
# L1norm mean is: [2.20273657]
# L2norm mean is: [0.50731349]
# MSE_F mean is: [0.32799328]
# MSE_Y mean is: [0.46962676]
#
# R2= 0.670180713217795
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.025119782121285714
# Average data variance is:  1.0
# Time taken to draw data :  0.033145904541015625
# run time is : 42.09357571601868
# RUN 16
# Runtime mean is: [32.46692735]
# Weighted accuracy mean is: [[0.81315789 0.88782895 0.83256579 0.66217105]]
# TPR mean is: [[0.94117647 0.89411765 0.71764706 0.32941176]]
# PPV mean is: [[0.14009802 0.35403361 0.50614337 0.58921569]]
# MCC mean is: [[0.29180942 0.5125158  0.56222287 0.41127211]]
# L1norm mean is: [2.24267876]
# L2norm mean is: [0.52238113]
# MSE_F mean is: [0.33075652]
# MSE_Y mean is: [0.47440985]
#
# R2= 0.6737629696200876
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.013021926251460857
# Average data variance is:  1.0
# Time taken to draw data :  0.03777718544006348
# run time is : 27.729702949523926
# RUN 17
# Runtime mean is: [32.20453931]
# Weighted accuracy mean is: [[0.81455108 0.89009288 0.83436533 0.65789474]]
# TPR mean is: [[0.94444444 0.9        0.73333333 0.34444444]]
# PPV mean is: [[0.13908987 0.34898496 0.50117244 0.59814815]]
# MCC mean is: [[0.29088699 0.51035849 0.56550275 0.42484644]]
# L1norm mean is: [2.28406759]
# L2norm mean is: [0.52764096]
# MSE_F mean is: [0.3402036]
# MSE_Y mean is: [0.46930065]
#
# R2= 0.6677520369209993
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.03972120775167375
# Average data variance is:  1.0
# Time taken to draw data :  0.03135085105895996
# run time is : 43.92023587226868
# RUN 18
# Runtime mean is: [32.82197278]
# Weighted accuracy mean is: [[0.81432749 0.89210526 0.84152047 0.66549708]]
# TPR mean is: [[0.93684211 0.89473684 0.73684211 0.33684211]]
# PPV mean is: [[0.13730951 0.3401867  0.49584757 0.58421053]]
# MCC mean is: [[0.2860251  0.50040344 0.56391331 0.41451905]]
# L1norm mean is: [2.30801176]
# L2norm mean is: [0.53228434]
# MSE_F mean is: [0.33807754]
# MSE_Y mean is: [0.47240133]
#
# R2= 0.6574843035362838
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.00931039846477869
# Average data variance is:  1.0
# Time taken to draw data :  0.032323598861694336
# run time is : 28.586470127105713
# RUN 19
# Runtime mean is: [32.61092832]
# Weighted accuracy mean is: [[0.80941828 0.88753463 0.84293629 0.66149584]]
# TPR mean is: [[0.94 0.9  0.74 0.33]]
# PPV mean is: [[0.1408607  0.34103451 0.49605519 0.58      ]]
# MCC mean is: [[0.29213626 0.50381337 0.5661606  0.40854125]]
# L1norm mean is: [2.27338519]
# L2norm mean is: [0.52746678]
# MSE_F mean is: [0.34007516]
# MSE_Y mean is: [0.47443826]
#
# R2= 0.6566768531325978
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.048120794104604334
# Average data variance is:  1.0
# Time taken to draw data :  0.0322270393371582
# run time is : 44.44504451751709
# RUN 20
# Runtime mean is: [33.17517008]
# Weighted accuracy mean is: [[0.81394737 0.89078947 0.84473684 0.65815789]]
# TPR mean is: [[0.94285714 0.9047619  0.75238095 0.33333333]]
# PPV mean is: [[0.14297139 0.3486043  0.49888855 0.6       ]]
# MCC mean is: [[0.2961882  0.51259593 0.57393846 0.41873928]]
# L1norm mean is: [2.23971095]
# L2norm mean is: [0.52203299]
# MSE_F mean is: [0.33156183]
# MSE_Y mean is: [0.46855895]
#
# R2= 0.662466728266252
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.020888829177460905
# Average data variance is:  1.0
# Time taken to draw data :  0.03286385536193848
# run time is : 20.91606044769287
# RUN 21
# Runtime mean is: [32.61861794]
# Weighted accuracy mean is: [[0.81729323 0.89473684 0.85112782 0.66015038]]
# TPR mean is: [[0.93636364 0.9        0.75454545 0.34545455]]
# PPV mean is: [[0.1408017  0.33881925 0.48578117 0.58977273]]
# MCC mean is: [[0.2907538  0.50067399 0.56406512 0.41969348]]
# L1norm mean is: [2.35436083]
# L2norm mean is: [0.54469638]
# MSE_F mean is: [0.34658691]
# MSE_Y mean is: [0.48487096]
#
# R2= 0.6561282883682557
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.028287582813837964
# Average data variance is:  1.0
# Time taken to draw data :  0.03490638732910156
# run time is : 44.569828271865845
# RUN 22
# Runtime mean is: [33.13892958]
# Weighted accuracy mean is: [[0.81196172 0.88875598 0.84976077 0.665311  ]]
# TPR mean is: [[0.93913043 0.90434783 0.75652174 0.34782609]]
# PPV mean is: [[0.14040071 0.33158423 0.4733559  0.575     ]]
# MCC mean is: [[0.29085321 0.49451277 0.55450245 0.41321133]]
# L1norm mean is: [2.45350452]
# L2norm mean is: [0.565733]
# MSE_F mean is: [0.35105696]
# MSE_Y mean is: [0.4955011]
#
# R2= 0.6857305873693424
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.0022032914982208058
# Average data variance is:  1.0
# Time taken to draw data :  0.03490757942199707
# run time is : 28.60175085067749
# RUN 23
# Runtime mean is: [32.95052378]
# Weighted accuracy mean is: [[0.81258581 0.88810069 0.84828375 0.66544622]]
# TPR mean is: [[0.94166667 0.90833333 0.76666667 0.375     ]]
# PPV mean is: [[0.14050306 0.32873314 0.47967441 0.59270833]]
# MCC mean is: [[0.29176104 0.49364492 0.56381429 0.43766086]]
# L1norm mean is: [2.45712827]
# L2norm mean is: [0.56522766]
# MSE_F mean is: [0.35173468]
# MSE_Y mean is: [0.49544598]
#
# R2= 0.6742361310048669
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.02038945159263472
# Average data variance is:  1.0
# Time taken to draw data :  0.03180956840515137
# run time is : 43.118783950805664
# RUN 24
# Runtime mean is: [33.35787191]
# Weighted accuracy mean is: [[0.81381579 0.88969298 0.85394737 0.67938596]]
# TPR mean is: [[0.944 0.904 0.76  0.376]]
# PPV mean is: [[0.14028834 0.32225048 0.46905886 0.585     ]]
# MCC mean is: [[0.29206496 0.4859317  0.55342716 0.43489126]]
# L1norm mean is: [2.51472089]
# L2norm mean is: [0.58095786]
# MSE_F mean is: [0.35104821]
# MSE_Y mean is: [0.49659149]
#
# R2= 0.665275936465014
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.027943608170301865
# Average data variance is:  1.0
# Time taken to draw data :  0.0337681770324707
# run time is : 28.329296827316284
# RUN 25
# Runtime mean is: [33.16507891]
# Weighted accuracy mean is: [[0.81452632 0.88589474 0.84947368 0.67957895]]
# TPR mean is: [[0.94615385 0.9        0.76153846 0.39230769]]
# PPV mean is: [[0.13970033 0.31684924 0.46200714 0.58173077]]
# MCC mean is: [[0.29163845 0.47959635 0.54892492 0.44158233]]
# L1norm mean is: [2.56821205]
# L2norm mean is: [0.59111148]
# MSE_F mean is: [0.35275323]
# MSE_Y mean is: [0.50222859]
#
# R2= 0.6561443477631892
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.017068834469966567
# Average data variance is:  0.9999999999999999
# Time taken to draw data :  0.03390932083129883
# run time is : 44.58600163459778
# RUN 26
# Runtime mean is: [33.58866706]
# Weighted accuracy mean is: [[0.8145749  0.88279352 0.84939271 0.68724696]]
# TPR mean is: [[0.94814815 0.9037037  0.77037037 0.39259259]]
# PPV mean is: [[0.14049996 0.3236326  0.4713508  0.59722222]]
# MCC mean is: [[0.29351364 0.48732416 0.55956513 0.44829039]]
# L1norm mean is: [2.52816499]
# L2norm mean is: [0.58171684]
# MSE_F mean is: [0.35929629]
# MSE_Y mean is: [0.50289278]
#
# R2= 0.6615509542024669
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.009939929479793922
# Average data variance is:  1.0
# Time taken to draw data :  0.031914710998535156
# run time is : 28.56320285797119
# RUN 27
# Runtime mean is: [33.40974281]
# Weighted accuracy mean is: [[0.81637427 0.88615984 0.8545809  0.6877193 ]]
# TPR mean is: [[0.95       0.90714286 0.77857143 0.4       ]]
# PPV mean is: [[0.14143448 0.32397905 0.48002704 0.60267857]]
# MCC mean is: [[0.29554666 0.48942396 0.56944532 0.45569466]]
# L1norm mean is: [2.5172155]
# L2norm mean is: [0.58316459]
# MSE_F mean is: [0.36252251]
# MSE_Y mean is: [0.50748797]
#
# R2= 0.6665805151160775
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.018276289178472873
# Average data variance is:  1.0
# Time taken to draw data :  0.03312993049621582
# run time is : 44.33707857131958
# RUN 28
# Runtime mean is: [33.78709722]
# Weighted accuracy mean is: [[0.81823308 0.88834586 0.8593985  0.69154135]]
# TPR mean is: [[0.94482759 0.90344828 0.77931034 0.3862069 ]]
# PPV mean is: [[0.1401872  0.32265958 0.48317882 0.58189655]]
# MCC mean is: [[0.29220061 0.48759448 0.57244308 0.43918598]]
# L1norm mean is: [2.4990038]
# L2norm mean is: [0.57821563]
# MSE_F mean is: [0.36274396]
# MSE_Y mean is: [0.50415014]
#
# R2= 0.6484274969153005
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.03240700392694609
# Average data variance is:  1.0
# Time taken to draw data :  0.03287839889526367
# run time is : 28.776127815246582
# RUN 29
# Runtime mean is: [33.62058105]
# Weighted accuracy mean is: [[0.81488203 0.88693285 0.86025408 0.68475499]]
# TPR mean is: [[0.94666667 0.90666667 0.78666667 0.4       ]]
# PPV mean is: [[0.14072262 0.32301537 0.48373953 0.58472222]]
# MCC mean is: [[0.29360819 0.48954529 0.57630322 0.44837481]]
# L1norm mean is: [2.50038302]
# L2norm mean is: [0.58017628]
# MSE_F mean is: [0.36582521]
# MSE_Y mean is: [0.508995]
#
# R2= 0.6541034863080866
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.05638683542602628
# Average data variance is:  1.0
# Time taken to draw data :  0.0331575870513916
# run time is : 19.387487173080444
# RUN 30
# Runtime mean is: [33.16195094]
# Weighted accuracy mean is: [[0.81631579 0.88894737 0.86403509 0.69157895]]
# TPR mean is: [[0.94193548 0.89677419 0.78064516 0.4       ]]
# PPV mean is: [[0.14079148 0.31720381 0.47693268 0.5766129 ]]
# MCC mean is: [[0.29270772 0.48083953 0.56930233 0.4445061 ]]
# L1norm mean is: [2.5260884]
# L2norm mean is: [0.58814694]
# MSE_F mean is: [0.36854529]
# MSE_Y mean is: [0.50580284]
#
# R2= 0.6714054495516456
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.057826033024621935
# Average data variance is:  0.9999999999999999
# Time taken to draw data :  0.03169369697570801
# run time is : 28.6837420463562
# RUN 31
# Runtime mean is: [33.02244819]
# Weighted accuracy mean is: [[0.81494058 0.88302207 0.86061121 0.69117148]]
# TPR mean is: [[0.9375  0.89375 0.78125 0.4    ]]
# PPV mean is: [[0.14119944 0.31690658 0.47452853 0.57109375]]
# MCC mean is: [[0.29238662 0.48009621 0.56823987 0.44212844]]
# L1norm mean is: [2.51058299]
# L2norm mean is: [0.58573024]
# MSE_F mean is: [0.36372145]
# MSE_Y mean is: [0.50228302]
#
# R2= 0.6921948062727995
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.1043615124426314
# Average data variance is:  1.0
# Time taken to draw data :  0.03314471244812012
# run time is : 44.09000754356384
# RUN 32
# Runtime mean is: [33.35827902]
# Weighted accuracy mean is: [[0.81398026 0.88207237 0.86085526 0.69095395]]
# TPR mean is: [[0.92727273 0.87878788 0.76969697 0.38787879]]
# PPV mean is: [[0.13931301 0.31163235 0.47024989 0.55378788]]
# MCC mean is: [[0.28667739 0.47075702 0.56097335 0.42773747]]
# L1norm mean is: [2.50483466]
# L2norm mean is: [0.58323102]
# MSE_F mean is: [0.36048592]
# MSE_Y mean is: [0.50113573]
#
# R2= 0.6590453962617344
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.03062406760087102
# Average data variance is:  1.0
# Time taken to draw data :  0.032195329666137695
# run time is : 18.464953422546387
# RUN 33
# Runtime mean is: [32.92070927]
# Weighted accuracy mean is: [[0.80797448 0.87464115 0.8553429  0.68484848]]
# TPR mean is: [[0.92941176 0.88235294 0.77647059 0.39411765]]
# PPV mean is: [[0.1399594  0.30981964 0.46978799 0.55514706]]
# MCC mean is: [[0.28831242 0.47040627 0.56366714 0.43218482]]
# L1norm mean is: [2.51932709]
# L2norm mean is: [0.58697085]
# MSE_F mean is: [0.36107181]
# MSE_Y mean is: [0.49928311]
#
# R2= 0.6744525353845705
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.019693890473272073
# Average data variance is:  1.0
# Time taken to draw data :  0.030269145965576172
# run time is : 42.28578448295593
# RUN 34
# Runtime mean is: [33.18869609]
# Weighted accuracy mean is: [[0.80959752 0.87600619 0.85866873 0.6879257 ]]
# TPR mean is: [[0.93142857 0.88571429 0.78285714 0.41142857]]
# PPV mean is: [[0.13962357 0.30589376 0.46476884 0.55119048]]
# MCC mean is: [[0.28827254 0.46722226 0.56204574 0.43758699]]
# L1norm mean is: [2.58307604]
# L2norm mean is: [0.59709877]
# MSE_F mean is: [0.3620292]
# MSE_Y mean is: [0.5032665]
#
# R2= 0.6768421201538708
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.004074635201146229
# Average data variance is:  1.0
# Time taken to draw data :  0.032778263092041016
# run time is : 27.397321462631226
# RUN 35
# Runtime mean is: [33.02821243]
# Weighted accuracy mean is: [[0.80992481 0.87593985 0.86090226 0.69578947]]
# TPR mean is: [[0.93333333 0.88888889 0.78888889 0.41111111]]
# PPV mean is: [[0.14022542 0.31282881 0.47963637 0.56365741]]
# MCC mean is: [[0.28977243 0.47450763 0.57421114 0.44272901]]
# L1norm mean is: [2.54632649]
# L2norm mean is: [0.58816978]
# MSE_F mean is: [0.3565047]
# MSE_Y mean is: [0.50133744]
#
# R2= 0.6749126930834013
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.034067133706892516
# Average data variance is:  1.0
# Time taken to draw data :  0.030833005905151367
# run time is : 38.880369663238525
# RUN 36
# Runtime mean is: [33.18678328]
# Weighted accuracy mean is: [[0.81140351 0.87880117 0.86476608 0.69590643]]
# TPR mean is: [[0.93513514 0.89189189 0.78918919 0.41081081]]
# PPV mean is: [[0.14163305 0.31788749 0.48211724 0.57545045]]
# MCC mean is: [[0.2924012  0.48028438 0.57643192 0.44759309]]
# L1norm mean is: [2.51605541]
# L2norm mean is: [0.58201629]
# MSE_F mean is: [0.35201419]
# MSE_Y mean is: [0.50021213]
#
# R2= 0.6665978054717606
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.026368275291408037
# Average data variance is:  1.0
# Time taken to draw data :  0.033869028091430664
# run time is : 27.223621606826782
# RUN 37
# Runtime mean is: [33.03026135]
# Weighted accuracy mean is: [[0.81351351 0.88136558 0.86529161 0.69601707]]
# TPR mean is: [[0.93157895 0.88947368 0.78947368 0.40526316]]
# PPV mean is: [[0.14119534 0.3190914  0.49048258 0.58662281]]
# MCC mean is: [[0.29091872 0.48095897 0.58203829 0.4473429 ]]
# L1norm mean is: [2.49079041]
# L2norm mean is: [0.57549783]
# MSE_F mean is: [0.35083813]
# MSE_Y mean is: [0.49850721]
#
# R2= 0.6508304739427303
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.03209970886557939
# Average data variance is:  1.0
# Time taken to draw data :  0.032309532165527344
# run time is : 42.11305093765259
# RUN 38
# Runtime mean is: [33.26354364]
# Weighted accuracy mean is: [[0.81191136 0.88088643 0.86606648 0.6934903 ]]
# TPR mean is: [[0.91794872 0.87692308 0.77948718 0.4       ]]
# PPV mean is: [[0.13912895 0.31518308 0.48523211 0.58012821]]
# MCC mean is: [[0.28433498 0.47369525 0.57472243 0.44173477]]
# L1norm mean is: [2.49116214]
# L2norm mean is: [0.5760484]
# MSE_F mean is: [0.34975094]
# MSE_Y mean is: [0.4964305]
#
# R2= 0.6289816176150459
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.019299195491685614
# Average data variance is:  1.0
# Time taken to draw data :  0.03384256362915039
# run time is : 27.19831156730652
# RUN 39
# Runtime mean is: [33.1122869]
# Weighted accuracy mean is: [[0.8048583  0.87489879 0.8611336  0.69082321]]
# TPR mean is: [[0.92  0.87  0.775 0.39 ]]
# PPV mean is: [[0.13862691 0.31171527 0.48060131 0.565625  ]]
# MCC mean is: [[0.28396649 0.46841837 0.56991336 0.42937561]]
# L1norm mean is: [2.50475684]
# L2norm mean is: [0.57838326]
# MSE_F mean is: [0.35445558]
# MSE_Y mean is: [0.50086306]
#
# R2= 0.6461982046351451
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.030258707464149544
# Average data variance is:  1.0
# Time taken to draw data :  0.032541513442993164
# run time is : 43.77268052101135
# RUN 40
# Runtime mean is: [33.37266896]
# Weighted accuracy mean is: [[0.80486842 0.87118421 0.85868421 0.68539474]]
# TPR mean is: [[0.92195122 0.87317073 0.77560976 0.3902439 ]]
# PPV mean is: [[0.13808184 0.30831767 0.47375737 0.55670732]]
# MCC mean is: [[0.2834828  0.4657488  0.56440629 0.42449854]]
# L1norm mean is: [2.55229407]
# L2norm mean is: [0.58523259]
# MSE_F mean is: [0.35832518]
# MSE_Y mean is: [0.50377298]
#
# R2= 0.625144710510123
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.012415829504954585
# Average data variance is:  1.0
# Time taken to draw data :  0.03188300132751465
# run time is : 27.18877363204956
# RUN 41
# Runtime mean is: [33.22580168]
# Weighted accuracy mean is: [[0.80474968 0.87124519 0.857638   0.68472401]]
# TPR mean is: [[0.91904762 0.87142857 0.77619048 0.3952381 ]]
# PPV mean is: [[0.13751527 0.30511756 0.46928016 0.55238095]]
# MCC mean is: [[0.28188663 0.46205798 0.56135778 0.42486123]]
# L1norm mean is: [2.5818236]
# L2norm mean is: [0.59055451]
# MSE_F mean is: [0.36449917]
# MSE_Y mean is: [0.50612239]
#
# R2= 0.6868803226541894
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.03031438298925549
# Average data variance is:  1.0
# Time taken to draw data :  0.03339362144470215
# run time is : 41.72634530067444
# RUN 42
# Runtime mean is: [33.42383747]
# Weighted accuracy mean is: [[0.80313283 0.86954887 0.85739348 0.68684211]]
# TPR mean is: [[0.91162791 0.86511628 0.76744186 0.39069767]]
# PPV mean is: [[0.13672301 0.3043643  0.4661186  0.54728682]]
# MCC mean is: [[0.27897605 0.45966769 0.55594121 0.42029762]]
# L1norm mean is: [2.57197371]
# L2norm mean is: [0.58817295]
# MSE_F mean is: [0.36539206]
# MSE_Y mean is: [0.50272891]
#
# R2= 0.6668713934717317
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.03708622034840748
# Average data variance is:  1.0
# Time taken to draw data :  0.0348658561706543
# run time is : 27.041242837905884
# RUN 43
# Runtime mean is: [33.27912002]
# Weighted accuracy mean is: [[0.7998776  0.86695226 0.85324357 0.68457772]]
# TPR mean is: [[0.90909091 0.86363636 0.76363636 0.38636364]]
# PPV mean is: [[0.13675047 0.30754794 0.46916136 0.55757576]]
# MCC mean is: [[0.27849589 0.46215631 0.55646407 0.4207019 ]]
# L1norm mean is: [2.54310825]
# L2norm mean is: [0.58143498]
# MSE_F mean is: [0.36170375]
# MSE_Y mean is: [0.49860704]
#
# R2= 0.6585145392789092
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.04161179504273189
# Average data variance is:  1.0
# Time taken to draw data :  0.032442569732666016
# run time is : 41.6150279045105
# RUN 44
# Runtime mean is: [33.46470676]
# Weighted accuracy mean is: [[0.79916268 0.86710526 0.85179426 0.6826555 ]]
# TPR mean is: [[0.91111111 0.86222222 0.76       0.39111111]]
# PPV mean is: [[0.13635707 0.30377867 0.46349746 0.5562963 ]]
# MCC mean is: [[0.2782981  0.45761614 0.55085678 0.42294514]]
# L1norm mean is: [2.58541214]
# L2norm mean is: [0.59257731]
# MSE_F mean is: [0.35934517]
# MSE_Y mean is: [0.49899869]
#
# R2= 0.6469949789306219
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.05962491397276201
# Average data variance is:  1.0
# Time taken to draw data :  0.03371620178222656
# run time is : 14.582152366638184
# RUN 45
# Runtime mean is: [33.054545]
# Weighted accuracy mean is: [[0.79929825 0.86491228 0.84935673 0.68491228]]
# TPR mean is: [[0.90434783 0.85652174 0.75652174 0.39565217]]
# PPV mean is: [[0.13536907 0.30043566 0.45885621 0.56050725]]
# MCC mean is: [[0.27511189 0.45265526 0.54624836 0.42800308]]
# L1norm mean is: [2.60189871]
# L2norm mean is: [0.59499263]
# MSE_F mean is: [0.35858913]
# MSE_Y mean is: [0.49720113]
#
# R2= 0.6669265544468873
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.01054853613542694
# Average data variance is:  1.0
# Time taken to draw data :  0.03212761878967285
# run time is : 41.674864530563354
# RUN 46
# Runtime mean is: [33.23825381]
# Weighted accuracy mean is: [[0.79588101 0.86155606 0.847254   0.68729977]]
# TPR mean is: [[0.89787234 0.85106383 0.75319149 0.39574468]]
# PPV mean is: [[0.13442312 0.29758951 0.45489602 0.55567376]]
# MCC mean is: [[0.27206126 0.44836049 0.54227022 0.42588482]]
# L1norm mean is: [2.60991645]
# L2norm mean is: [0.59619421]
# MSE_F mean is: [0.3579895]
# MSE_Y mean is: [0.49637196]
#
# R2= 0.6677321817089614
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.011275144659735017
# Average data variance is:  1.0
# Time taken to draw data :  0.033843278884887695
# run time is : 27.098484754562378
# RUN 47
# Runtime mean is: [33.11064262]
# Weighted accuracy mean is: [[0.79260918 0.85856663 0.84535274 0.68712206]]
# TPR mean is: [[0.9        0.85416667 0.75833333 0.39166667]]
# PPV mean is: [[0.13498285 0.29940255 0.45843985 0.55104167]]
# MCC mean is: [[0.27352391 0.45138396 0.54718098 0.42177526]]
# L1norm mean is: [2.59426261]
# L2norm mean is: [0.59280391]
# MSE_F mean is: [0.35674634]
# MSE_Y mean is: [0.49441738]
#
# R2= 0.6519023732414002
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.043378258239057416
# Average data variance is:  1.0
# Time taken to draw data :  0.03183174133300781
# run time is : 41.66697549819946
# RUN 48
# Runtime mean is: [33.28559035]
# Weighted accuracy mean is: [[0.79407895 0.86063596 0.84824561 0.68508772]]
# TPR mean is: [[0.89795918 0.85306122 0.75510204 0.38367347]]
# PPV mean is: [[0.13562946 0.30689773 0.46439006        nan]]
# MCC mean is: [[0.27408086 0.45676083 0.54939382 0.4131676 ]]
# L1norm mean is: [2.56250316]
# L2norm mean is: [0.58571116]
# MSE_F mean is: [0.35191441]
# MSE_Y mean is: [0.49111762]
#
# R2= 0.7027789528656214
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.009578360334282976
# Average data variance is:  1.0000000000000002
# Time taken to draw data :  0.033875226974487305
# C:\Users\hughw\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\hughw\anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hughw\Documents\MSC project\GP algorithms\Master function files\GP_funcs_ZTMFSS.py:2032: RuntimeWarning: invalid value encountered in true_divide
#   MCC[j,i]=(TP*TN-FP*FN)/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
# run time is : 21.011659622192383
# RUN 49
# Runtime mean is: [33.0404142]
# Weighted accuracy mean is: [[0.79409237 0.86122449 0.8471536  0.68131042]]
# TPR mean is: [[0.9   0.856 0.76  0.392]]
# PPV mean is: [[0.13614267 0.30790264 0.46510226        nan]]
# MCC mean is: [[0.27544461 0.45899766 0.55217089 0.41920126]]
# L1norm mean is: [2.55629626]
# L2norm mean is: [0.58583606]
# MSE_F mean is: [0.35071986]
# MSE_Y mean is: [0.49057808]
#
# R2= 0.6496737966259072
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.07348664634452057
# Average data variance is:  1.0
# Time taken to draw data :  0.03308582305908203
# run time is : 41.63550806045532
# RUN 50
# Runtime mean is: [33.20923404]
# Weighted accuracy mean is: [[0.79547368 0.86305263 0.84968421 0.68547368]]
# TPR mean is: [[0.90196078 0.85490196 0.76078431 0.38823529]]
# PPV mean is: [[0.13605319 0.30970847 0.4690545         nan]]
# MCC mean is: [[0.27578963 0.46049385 0.55536069 0.41676522]]
# L1norm mean is: [2.54300134]
# L2norm mean is: [0.58304502]
# MSE_F mean is: [0.35019964]
# MSE_Y mean is: [0.48976638]
#
# R2= 0.6358483708669438
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.009861913056611568
# Average data variance is:  1.0
# Time taken to draw data :  0.033876895904541016
# run time is : 27.03466820716858
# RUN 51
# Runtime mean is: [33.09079993]
# Weighted accuracy mean is: [[0.79607843 0.86315789 0.8504644  0.68369453]]
# TPR mean is: [[0.90384615 0.85384615 0.76153846 0.39230769]]
# PPV mean is: [[0.13626484 0.31229954 0.47541884        nan]]
# MCC mean is: [[0.27663283 0.46258371 0.55986286 0.42349223]]
# L1norm mean is: [2.52339585]
# L2norm mean is: [0.57836787]
# MSE_F mean is: [0.34697059]
# MSE_Y mean is: [0.48729949]
#
# R2= 0.6597074763973991
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.010190928747457684
# Average data variance is:  1.0
# Time taken to draw data :  0.03291201591491699
# run time is : 41.506736278533936
# RUN 52
# Runtime mean is: [33.24987776]
# Weighted accuracy mean is: [[0.79706478 0.86336032 0.85131579 0.68593117]]
# TPR mean is: [[0.90566038 0.85660377 0.76603774 0.39245283]]
# PPV mean is: [[0.13706307 0.31498343 0.47992576        nan]]
# MCC mean is: [[0.27835454 0.46616821 0.56507697 0.42725086]]
# L1norm mean is: [2.50102501]
# L2norm mean is: [0.57371079]
# MSE_F mean is: [0.34507059]
# MSE_Y mean is: [0.48990848]
#
# R2= 0.6575485516911357
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.00830868797247089
# Average data variance is:  1.0
# Time taken to draw data :  0.031980037689208984
# run time is : 27.039955139160156
# RUN 53
# Runtime mean is: [33.13516631]
# Weighted accuracy mean is: [[0.79860973 0.8653426  0.85392254 0.68619662]]
# TPR mean is: [[0.90740741 0.85925926 0.76296296 0.39259259]]
# PPV mean is: [[0.13771772 0.31429443 0.47721109        nan]]
# MCC mean is: [[0.27984734 0.46660323 0.56218366 0.42714369]]
# L1norm mean is: [2.49772336]
# L2norm mean is: [0.57334471]
# MSE_F mean is: [0.34894793]
# MSE_Y mean is: [0.49117312]
#
# R2= 0.6807023224253889
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.02779492612880847
# Average data variance is:  1.0
# Time taken to draw data :  0.03114008903503418
# run time is : 20.002164125442505
# RUN 54
# Runtime mean is: [32.89663832]
# Weighted accuracy mean is: [[0.8        0.8665692  0.85233918 0.68625731]]
# TPR mean is: [[0.90909091 0.86181818 0.76727273 0.4       ]]
# PPV mean is: [[0.13767076 0.31151254 0.47248709        nan]]
# MCC mean is: [[0.28020211 0.4643426  0.5595942  0.42972593]]
# L1norm mean is: [2.54130214]
# L2norm mean is: [0.58057808]
# MSE_F mean is: [0.35137367]
# MSE_Y mean is: [0.49373416]
#
# R2= 0.6332396149392276
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.018107129705768915
# Average data variance is:  1.0
# Time taken to draw data :  0.03291177749633789
# run time is : 16.823928117752075
# RUN 55
# Runtime mean is: [32.60988777]
# Weighted accuracy mean is: [[0.80057416 0.86650718 0.85330144 0.68966507]]
# TPR mean is: [[0.91071429 0.86428571 0.77142857 0.40357143]]
# PPV mean is: [[0.13783841 0.31064907 0.47091795        nan]]
# MCC mean is: [[0.28090628 0.46450941 0.56019943 0.43136739]]
# L1norm mean is: [2.55010697]
# L2norm mean is: [0.58289237]
# MSE_F mean is: [0.3532202]
# MSE_Y mean is: [0.49629796]
#
# R2= 0.6827534179280479
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.05433961561997223
# Average data variance is:  1.0
# Time taken to draw data :  0.033181190490722656
# run time is : 41.56578016281128
# RUN 56
# Runtime mean is: [32.76727769]
# Weighted accuracy mean is: [[0.80140977 0.86757519 0.85516917 0.69135338]]
# TPR mean is: [[0.9122807  0.86666667 0.76842105 0.40350877]]
# PPV mean is: [[0.13816142 0.31104704 0.47318255        nan]]
# MCC mean is: [[0.28184526 0.46594115 0.56052834 0.4347241 ]]
# L1norm mean is: [2.53737468]
# L2norm mean is: [0.58040522]
# MSE_F mean is: [0.35292422]
# MSE_Y mean is: [0.49779107]
#
# R2= 0.6667336975758852
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.023997929587718153
# Average data variance is:  1.0
# Time taken to draw data :  0.03253030776977539
# run time is : 26.983949184417725
# RUN 57
# Runtime mean is: [32.66781296]
# Weighted accuracy mean is: [[0.80240074 0.86897507 0.85401662 0.69150508]]
# TPR mean is: [[0.91034483 0.86551724 0.76896552 0.40689655]]
# PPV mean is: [[0.13774977 0.31717841 0.48226561        nan]]
# MCC mean is: [[0.28071765 0.4702327  0.56620469 0.44044558]]
# L1norm mean is: [2.5179263]
# L2norm mean is: [0.57548285]
# MSE_F mean is: [0.35119258]
# MSE_Y mean is: [0.49510104]
#
# R2= 0.6550021675342513
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.028240880678867493
# Average data variance is:  1.0
# Time taken to draw data :  0.03156471252441406
# run time is : 41.48953700065613
# RUN 58
# Runtime mean is: [32.81759418]
# Weighted accuracy mean is: [[0.80127042 0.86932849 0.85480944 0.69337568]]
# TPR mean is: [[0.91186441 0.86779661 0.76271186 0.4       ]]
# PPV mean is: [[0.13748199 0.31950666 0.48539105        nan]]
# MCC mean is: [[0.28062422 0.47332303 0.56504186 0.4329804 ]]
# L1norm mean is: [2.50137261]
# L2norm mean is: [0.57044563]
# MSE_F mean is: [0.34908837]
# MSE_Y mean is: [0.49355476]
#
# R2= 0.671991173742632
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.009410651203397334
# Average data variance is:  1.0
# Time taken to draw data :  0.03387713432312012
# C:\Users\hughw\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\hughw\anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hughw\Documents\MSC project\GP algorithms\Master function files\GP_funcs_ZTMFSS.py:2032: RuntimeWarning: invalid value encountered in true_divide
#   MCC[j,i]=(TP*TN-FP*FN)/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
# run time is : 26.981663465499878
# RUN 59
# Runtime mean is: [32.72056419]
# Weighted accuracy mean is: [[0.8014273  0.87100803 0.85209634 0.69009813]]
# TPR mean is: [[0.91333333 0.87       0.76       0.4       ]]
# PPV mean is: [[0.13708457 0.32013393 0.48563453        nan]]
# MCC mean is: [[0.28026075 0.47491101 0.56431862 0.43405735]]
# L1norm mean is: [2.49991609]
# L2norm mean is: [0.56918809]
# MSE_F mean is: [0.3502473]
# MSE_Y mean is: [0.49508092]
#
# R2= 0.6741326595966766
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.04539169882446855
# Average data variance is:  0.9999999999999999
# Time taken to draw data :  0.031882524490356445
# run time is : 41.485352754592896
# RUN 60
# Runtime mean is: [32.86449756]
# Weighted accuracy mean is: [[0.80131579 0.87236842 0.85096491 0.69017544]]
# TPR mean is: [[0.9147541  0.87213115 0.76065574 0.4       ]]
# PPV mean is: [[0.13688646 0.3191999  0.48587003        nan]]
# MCC mean is: [[0.28027247 0.4748909  0.56504879 0.4338509 ]]
# L1norm mean is: [2.50120664]
# L2norm mean is: [0.56927862]
# MSE_F mean is: [0.34957666]
# MSE_Y mean is: [0.49477307]
#
# R2= 0.6976828460544607
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.010079809766741906
# Average data variance is:  1.0
# Time taken to draw data :  0.03387737274169922
# run time is : 27.000386476516724
# RUN 61
# Runtime mean is: [32.77017863]
# Weighted accuracy mean is: [[0.80155306 0.8732528  0.85142364 0.69016393]]
# TPR mean is: [[0.91612903 0.87419355 0.76451613 0.4       ]]
# PPV mean is: [[0.13712241 0.31789176 0.48423689        nan]]
# MCC mean is: [[0.28102439 0.47440824 0.56550747 0.43487907]]
# L1norm mean is: [2.50169702]
# L2norm mean is: [0.56879098]
# MSE_F mean is: [0.34928409]
# MSE_Y mean is: [0.49332536]
#
# R2= 0.673443957790564
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.06854200736912201
# Average data variance is:  1.0
# Time taken to draw data :  0.030879735946655273
# run time is : 41.504629135131836
# RUN 62
# Runtime mean is: [32.90907398]
# Weighted accuracy mean is: [[0.80237691 0.87393888 0.85314092 0.69023769]]
# TPR mean is: [[0.91746032 0.87301587 0.76507937 0.4       ]]
# PPV mean is: [[0.13715044 0.31681411 0.48360527        nan]]
# MCC mean is: [[0.28141905 0.47323511 0.56556556 0.43382418]]
# L1norm mean is: [2.50127139]
# L2norm mean is: [0.56850722]
# MSE_F mean is: [0.35035071]
# MSE_Y mean is: [0.49751805]
#
# R2= 0.6605144960224738
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.011728019172452517
# Average data variance is:  1.0
# Time taken to draw data :  0.033876895904541016
# run time is : 26.903082609176636
# RUN 63
# Runtime mean is: [32.81547301]
# Weighted accuracy mean is: [[0.80292398 0.87335004 0.853467   0.69014202]]
# TPR mean is: [[0.91875 0.875   0.76875 0.40625]]
# PPV mean is: [[0.13701067 0.31896617 0.49167393        nan]]
# MCC mean is: [[0.28150495 0.4760371  0.5723536  0.44094813]]
# L1norm mean is: [2.49031401]
# L2norm mean is: [0.56542974]
# MSE_F mean is: [0.3491454]
# MSE_Y mean is: [0.4968119]
#
# R2= 0.6521093478501754
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.013974994838831531
# Average data variance is:  1.0
# Time taken to draw data :  0.030885934829711914
# run time is : 41.424845933914185
# RUN 64
# Runtime mean is: [32.94816111]
# Weighted accuracy mean is: [[0.80320724 0.87483553 0.85575658 0.69342105]]
# TPR mean is: [[0.91692308 0.87384615 0.76923077 0.40923077]]
# PPV mean is: [[0.13666106 0.31816156 0.49180203        nan]]
# MCC mean is: [[0.28050401 0.47513837 0.57291522 0.44595769]]
# L1norm mean is: [2.48735475]
# L2norm mean is: [0.56405944]
# MSE_F mean is: [0.34944175]
# MSE_Y mean is: [0.49754865]
#
# R2= 0.6804826495519651
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.03457760735907958
# Average data variance is:  1.0
# Time taken to draw data :  0.03146672248840332
# run time is : 26.84149169921875
# RUN 65
# Runtime mean is: [32.85587759]
# Weighted accuracy mean is: [[0.80218623 0.87433198 0.85611336 0.69506073]]
# TPR mean is: [[0.91818182 0.87272727 0.76969697 0.4030303 ]]
# PPV mean is: [[0.13669481 0.31940153 0.49192624        nan]]
# MCC mean is: [[0.28088861 0.47604997 0.57345982 0.43920075]]
# L1norm mean is: [2.47334273]
# L2norm mean is: [0.56095261]
# MSE_F mean is: [0.35056326]
# MSE_Y mean is: [0.49710907]
#
# R2= 0.6556185981544633
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.019631139604443675
# Average data variance is:  0.9999999999999999
# Time taken to draw data :  0.03244757652282715
# C:\Users\hughw\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\hughw\anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hughw\Documents\MSC project\GP algorithms\Master function files\GP_funcs_ZTMFSS.py:2032: RuntimeWarning: invalid value encountered in true_divide
#   MCC[j,i]=(TP*TN-FP*FN)/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
# run time is : 41.47565317153931
# RUN 66
# Runtime mean is: [32.98474634]
# Weighted accuracy mean is: [[0.80271132 0.87424242 0.85645933 0.69210526]]
# TPR mean is: [[0.91641791 0.87164179 0.77014925 0.40298507]]
# PPV mean is: [[0.13636035 0.31836569 0.49204674        nan]]
# MCC mean is: [[0.27992674 0.47492237 0.57398817 0.44007235]]
# L1norm mean is: [2.47406166]
# L2norm mean is: [0.56058365]
# MSE_F mean is: [0.35205701]
# MSE_Y mean is: [0.50037911]
#
# R2= 0.6645565215489438
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.012909384544755003
# Average data variance is:  1.0
# Time taken to draw data :  0.03427863121032715
# run time is : 27.07520818710327
# RUN 67
# Runtime mean is: [32.89804415]
# Weighted accuracy mean is: [[0.8017282  0.87368421 0.85679497 0.69214454]]
# TPR mean is: [[0.91764706 0.87352941 0.77352941 0.40294118]]
# PPV mean is: [[0.13672697 0.31981129 0.49531496        nan]]
# MCC mean is: [[0.28084353 0.4770744  0.57784438 0.44275805]]
# L1norm mean is: [2.46036897]
# L2norm mean is: [0.55719078]
# MSE_F mean is: [0.35247109]
# MSE_Y mean is: [0.50185016]
#
# R2= 0.691882647873732
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.028750525523020615
# Average data variance is:  1.0
# Time taken to draw data :  0.03032207489013672
# run time is : 41.52012062072754
# RUN 68
# Runtime mean is: [33.02322348]
# Weighted accuracy mean is: [[0.80263158 0.875      0.85874613 0.69226006]]
# TPR mean is: [[0.91884058 0.87246377 0.77391304 0.4057971 ]]
# ...
# Time taken to draw data :  0.035400390625
# run time is : 41.749282121658325
# RUN 76
# Runtime mean is: [32.83452407]
# Weighted accuracy mean is: [[0.80443213 0.87430748 0.85817175 0.68954294]]
# TPR mean is: [[0.91948052 0.87012987 0.76883117 0.39480519]]
# PPV mean is: [[0.13613303 0.32580156 0.4923836         nan]]
# MCC mean is: [[0.28003145 0.47779163 0.57289786 0.43139835]]
# L1norm mean is: [2.48606798]
# L2norm mean is: [0.56100819]
# MSE_F mean is: [0.35115984]
# MSE_Y mean is: [0.49738793]
#
# R2= 0.689243274372848
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.007853652471549673
# Average data variance is:  1.0
# Time taken to draw data :  0.03210020065307617
# run time is : 26.918489933013916
# RUN 77
# Runtime mean is: [32.75887073]
# Weighted accuracy mean is: [[0.80205058 0.87231716 0.8557758  0.68824334]]
# TPR mean is: [[0.92051282 0.87179487 0.77179487 0.39487179]]
# PPV mean is: [[0.13652449 0.32696649 0.49248124        nan]]
# MCC mean is: [[0.2809341  0.47963098 0.57437669 0.43127098]]
# L1norm mean is: [2.47953962]
# L2norm mean is: [0.56003348]
# MSE_F mean is: [0.35005341]
# MSE_Y mean is: [0.49674286]
#
# R2= 0.6779468706223419
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.016702734345375534
# Average data variance is:  1.0
# Time taken to draw data :  0.03211617469787598
# run time is : 22.96287703514099
# RUN 78
# Runtime mean is: [32.63506415]
# Weighted accuracy mean is: [[0.80290148 0.87348178 0.85728745 0.68825911]]
# TPR mean is: [[0.92151899 0.87341772 0.7721519  0.39746835]]
# PPV mean is: [[0.13665783 0.32557946 0.4913106         nan]]
# MCC mean is: [[0.281424   0.47887317 0.57388209 0.43241499]]
# L1norm mean is: [2.48780358]
# L2norm mean is: [0.56202663]
# MSE_F mean is: [0.35036228]
# MSE_Y mean is: [0.49530428]
#
# R2= 0.6581118142123663
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.0681690725740962
# Average data variance is:  0.9999999999999999
# Time taken to draw data :  0.03436470031738281
# run time is : 26.961073875427246
# RUN 79
# Runtime mean is: [32.56432845]
# Weighted accuracy mean is: [[0.80346436 0.87388408 0.85742838 0.68947368]]
# TPR mean is: [[0.9225 0.875  0.7675 0.395 ]]
# PPV mean is: [[0.13696574 0.32567639 0.48874064        nan]]
# MCC mean is: [[0.28218456 0.47971373 0.57041757 0.42986763]]
# L1norm mean is: [2.48825146]
# L2norm mean is: [0.56363528]
# MSE_F mean is: [0.35202634]
# MSE_Y mean is: [0.49610188]
#
# R2= 0.6928842538871326
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.011999526104811403
# Average data variance is:  1.0
# Time taken to draw data :  0.03244900703430176
# run time is : 41.40272045135498
# RUN 80
# Runtime mean is: [32.67362865]
# Weighted accuracy mean is: [[0.80421053 0.87480263 0.85513158 0.68822368]]
# TPR mean is: [[0.92345679 0.87654321 0.77037037 0.4       ]]
# PPV mean is: [[0.13698948 0.32606486 0.48887965        nan]]
# MCC mean is: [[0.28247719 0.48081112 0.57187225 0.43266408]]
# L1norm mean is: [2.49281463]
# L2norm mean is: [0.56580689]
# MSE_F mean is: [0.35176151]
# MSE_Y mean is: [0.49451515]
#
# R2= 0.6618469385839895
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.023413685817118352
# Average data variance is:  1.0000000000000002
# Time taken to draw data :  0.03305935859680176
# run time is : 16.92012095451355
# RUN 81
# Runtime mean is: [32.4817075]
# Weighted accuracy mean is: [[0.80461339 0.87576348 0.85659519 0.69064327]]
# TPR mean is: [[0.92195122 0.87317073 0.76829268 0.40243902]]
# PPV mean is: [[0.13684327 0.32452749 0.48749087        nan]]
# MCC mean is: [[0.28191121 0.47847344 0.57026078 0.43538294]]
# L1norm mean is: [2.49217122]
# L2norm mean is: [0.56596296]
# MSE_F mean is: [0.35024134]
# MSE_Y mean is: [0.49316505]
#
# R2= 0.6557671579032013
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.0038467762933523616
# Average data variance is:  1.0
# Time taken to draw data :  0.03390932083129883
# run time is : 41.49757623672485
# RUN 82
# Runtime mean is: [32.59051628]
# Weighted accuracy mean is: [[0.80397946 0.87406932 0.85558408 0.69191271]]
# TPR mean is: [[0.92289157 0.87228916 0.7686747  0.40722892]]
# PPV mean is: [[0.13720259 0.32345239 0.48563355        nan]]
# MCC mean is: [[0.28273683 0.47734448 0.56917409 0.43875002]]
# L1norm mean is: [2.49873767]
# L2norm mean is: [0.56783563]
# MSE_F mean is: [0.35253411]
# MSE_Y mean is: [0.49365942]
#
# R2= 0.6582972748978329
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.016609171182414263
# Average data variance is:  0.9999999999999997
# Time taken to draw data :  0.030614852905273438
# run time is : 26.988526821136475
# RUN 83
# Runtime mean is: [32.52400747]
# Weighted accuracy mean is: [[0.80475587 0.87355739 0.85561192 0.69429296]]
# TPR mean is: [[0.92380952 0.87380952 0.76904762 0.4047619 ]]
# PPV mean is: [[0.1378586  0.32621552 0.49175696        nan]]
# MCC mean is: [[0.2839785  0.48034628 0.57299054 0.43874211]]
# L1norm mean is: [2.48102286]
# L2norm mean is: [0.56387976]
# MSE_F mean is: [0.35125806]
# MSE_Y mean is: [0.49424348]
#
# R2= 0.6729946531563739
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.03211978040911567
# Average data variance is:  1.0
# Time taken to draw data :  0.0321047306060791
# run time is : 41.5226354598999
# RUN 84
# Runtime mean is: [32.63005137]
# Weighted accuracy mean is: [[0.80576441 0.87481203 0.85614035 0.69317043]]
# TPR mean is: [[0.92470588 0.87294118 0.76941176 0.40941176]]
# PPV mean is: [[0.13778472 0.32442372 0.48891276        nan]]
# MCC mean is: [[0.28408511 0.47835084 0.57096125 0.43987813]]
# L1norm mean is: [2.50519137]
# L2norm mean is: [0.56873154]
# MSE_F mean is: [0.3530113]
# MSE_Y mean is: [0.49558808]
#
# R2= 0.6624228186644294
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.007483224777655199
# Average data variance is:  1.0
# Time taken to draw data :  0.03374171257019043
# run time is : 26.98176097869873
# RUN 85
# Runtime mean is: [32.56454907]
# Weighted accuracy mean is: [[0.80600619 0.87393189 0.85591331 0.6952322 ]]
# TPR mean is: [[0.92325581 0.87209302 0.76976744 0.40930233]]
# PPV mean is: [[0.13768295 0.32375213 0.48904168        nan]]
# MCC mean is: [[0.28360808 0.47764467 0.57140193 0.44054929]]
# L1norm mean is: [2.50064174]
# L2norm mean is: [0.56758262]
# MSE_F mean is: [0.35435107]
# MSE_Y mean is: [0.49738726]
#
# R2= 0.6844129733040925
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.031185056878482827
# Average data variance is:  1.0
# Time taken to draw data :  0.03206181526184082
# run time is : 41.52681231498718
# RUN 86
# Runtime mean is: [32.66773152]
# Weighted accuracy mean is: [[0.80544676 0.87356181 0.85618115 0.69522644]]
# TPR mean is: [[0.92413793 0.87356322 0.77241379 0.4137931 ]]
# PPV mean is: [[0.13734976 0.32167288 0.48644532        nan]]
# MCC mean is: [[0.28320529 0.47574807 0.57027873 0.44163841]]
# L1norm mean is: [2.52855807]
# L2norm mean is: [0.5722005]
# MSE_F mean is: [0.3542304]
# MSE_Y mean is: [0.49936378]
#
# R2= 0.6908665076260271
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.016787391800717075
# Average data variance is:  1.0000000000000002
# Time taken to draw data :  0.031202316284179688
# run time is : 26.976258754730225
# RUN 87
# Runtime mean is: [32.60321527]
# Weighted accuracy mean is: [[0.80520266 0.87320024 0.8569873  0.69721718]]
# TPR mean is: [[0.92045455 0.87045455 0.76818182 0.41136364]]
# PPV mean is: [[0.13685431 0.32227887 0.49228117        nan]]
# MCC mean is: [[0.28155189 0.47533879 0.57087443 0.44159804]]
# L1norm mean is: [2.51625465]
# L2norm mean is: [0.56901864]
# MSE_F mean is: [0.35279419]
# MSE_Y mean is: [0.49816562]
#
# R2= 0.6514278874686273
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.019729842890666215
# Average data variance is:  1.0
# Time taken to draw data :  0.032454729080200195
# run time is : 41.284159421920776
# RUN 88
# Runtime mean is: [32.7009305]
# Weighted accuracy mean is: [[0.80340909 0.87206938 0.85520335 0.69611244]]
# TPR mean is: [[0.92134831 0.87191011 0.76853933 0.40898876]]
# PPV mean is: [[0.13707224 0.32240308 0.49573868        nan]]
# MCC mean is: [[0.282146   0.47613407 0.5733306  0.44155858]]
# L1norm mean is: [2.50713014]
# L2norm mean is: [0.56668284]
# MSE_F mean is: [0.35276094]
# MSE_Y mean is: [0.49724739]
#
# R2= 0.680428262045704
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.022811246965788946
# Average data variance is:  0.9999999999999999
# Time taken to draw data :  0.03390336036682129
# run time is : 26.941319704055786
# RUN 89
# Runtime mean is: [32.63710601]
# Weighted accuracy mean is: [[0.80402129 0.87291543 0.85564755 0.69503253]]
# TPR mean is: [[0.92222222 0.86888889 0.76666667 0.40888889]]
# PPV mean is: [[0.13709242 0.3215986  0.49439714        nan]]
# MCC mean is: [[0.2824098  0.47460891 0.57184617 0.4413353 ]]
# L1norm mean is: [2.5052037]
# L2norm mean is: [0.56618175]
# MSE_F mean is: [0.35146678]
# MSE_Y mean is: [0.4957006]
#
# R2= 0.6526622128891606
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.060807688295358896
# Average data variance is:  1.0
# Time taken to draw data :  0.03271317481994629
# run time is : 27.785160541534424
# RUN 90
# Runtime mean is: [32.58396468]
# Weighted accuracy mean is: [[0.80438596 0.87157895 0.85473684 0.69497076]]
# TPR mean is: [[0.92307692 0.87032967 0.76923077 0.40879121]]
# PPV mean is: [[0.13689413 0.32002687 0.49146171        nan]]
# MCC mean is: [[0.28226898 0.47343611 0.57030913 0.43974612]]
# L1norm mean is: [2.53429342]
# L2norm mean is: [0.5716908]
# MSE_F mean is: [0.35097582]
# MSE_Y mean is: [0.49772406]
#
# R2= 0.648534978478602
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.019324337514861546
# Average data variance is:  1.0
# Time taken to draw data :  0.0334625244140625
# run time is : 26.921367406845093
# RUN 91
# Runtime mean is: [32.52258172]
# Weighted accuracy mean is: [[0.8043956  0.87165992 0.85534991 0.69473684]]
# TPR mean is: [[0.92391304 0.87173913 0.76956522 0.40869565]]
# PPV mean is: [[0.13700462 0.32258696 0.4969893         nan]]
# MCC mean is: [[0.28267514 0.47621936 0.57378138 0.44173475]]
# L1norm mean is: [2.52122743]
# L2norm mean is: [0.56874427]
# MSE_F mean is: [0.3486914]
# MSE_Y mean is: [0.49675144]
#
# R2= 0.6714710909967039
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.04985172790691713
# Average data variance is:  1.0
# Time taken to draw data :  0.03408074378967285
# run time is : 29.028688669204712
# RUN 92
# Runtime mean is: [32.48517572]
# Weighted accuracy mean is: [[0.8048627  0.87282609 0.85583524 0.69479405]]
# TPR mean is: [[0.92473118 0.87311828 0.77204301 0.41075269]]
# PPV mean is: [[0.13675334 0.32069957 0.49388547        nan]]
# MCC mean is: [[0.28241859 0.47453567 0.57200146 0.44171321]]
# L1norm mean is: [2.54859445]
# L2norm mean is: [0.57268566]
# MSE_F mean is: [0.34782317]
# MSE_Y mean is: [0.49670659]
#
# R2= 0.677866153181564
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.013246869301736143
# Average data variance is:  1.0
# Time taken to draw data :  0.03126692771911621
# run time is : 9.256957292556763
# RUN 93
# Runtime mean is: [32.23823325]
# Weighted accuracy mean is: [[0.80475382 0.87255235 0.85631013 0.69564233]]
# TPR mean is: [[0.92340426 0.87234043 0.77234043 0.41276596]]
# PPV mean is: [[0.13658801 0.31899    0.49129094        nan]]
# MCC mean is: [[0.28185363 0.47258739 0.57017698 0.44208382]]
# L1norm mean is: [2.5623358]
# L2norm mean is: [0.57575399]
# MSE_F mean is: [0.34741891]
# MSE_Y mean is: [0.49510246]
#
# R2= 0.6799199190179215
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.062276051900954886
# Average data variance is:  1.0
# Time taken to draw data :  0.03234267234802246
# run time is : 31.70893669128418
# RUN 94
# Runtime mean is: [32.23282531]
# Weighted accuracy mean is: [[0.80414334 0.87166853 0.85610302 0.69652856]]
# TPR mean is: [[0.92421053 0.87157895 0.77263158 0.41263158]]
# PPV mean is: [[0.13661223 0.31738659 0.49138262        nan]]
# MCC mean is: [[0.28210662 0.47077925 0.57058416 0.44186676]]
# L1norm mean is: [2.56434427]
# L2norm mean is: [0.57607021]
# MSE_F mean is: [0.34716836]
# MSE_Y mean is: [0.49380711]
#
# R2= 0.6802328140509374
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.026655610549314448
# Average data variance is:  1.0
# Time taken to draw data :  0.03362631797790527
# run time is : 27.297748804092407
# RUN 95
# Runtime mean is: [32.18156726]
# Weighted accuracy mean is: [[0.80448753 0.87085873 0.85634349 0.69645429]]
# TPR mean is: [[0.925      0.87291667 0.775      0.41458333]]
# PPV mean is: [[0.13629734 0.31587646 0.48874421        nan]]
# MCC mean is: [[0.28170571 0.46961453 0.56927564 0.44222805]]
# L1norm mean is: [2.5815733]
# L2norm mean is: [0.57811459]
# MSE_F mean is: [0.34638668]
# MSE_Y mean is: [0.49409689]
#
# R2= 0.6704018974250235
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.014578119853112385
# Average data variance is:  1.0
# Time taken to draw data :  0.0324862003326416
# run time is : 41.39667844772339
# RUN 96
# Runtime mean is: [32.27673186]
# Weighted accuracy mean is: [[0.80422149 0.87088816 0.85696272 0.6973136 ]]
# TPR mean is: [[0.9257732  0.8742268  0.77731959 0.41030928]]
# PPV mean is: [[0.13636497 0.31658511 0.49014891        nan]]
# MCC mean is: [[0.28202463 0.47089156 0.5714273  0.43743129]]
# L1norm mean is: [2.57135669]
# L2norm mean is: [0.57593803]
# MSE_F mean is: [0.3460039]
# MSE_Y mean is: [0.49399207]
#
# R2= 0.661964083075546
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.020263754123629543
# Average data variance is:  1.0
# Time taken to draw data :  0.03330063819885254
# run time is : 26.918129682540894
# RUN 97
# Runtime mean is: [32.22220492]
# Weighted accuracy mean is: [[0.80461205 0.87178513 0.85827455 0.69522518]]
# TPR mean is: [[0.92653061 0.8755102  0.77755102 0.40612245]]
# PPV mean is: [[0.13667417 0.31760635 0.48922902        nan]]
# MCC mean is: [[0.28272273 0.47242594 0.57105869 0.43263328]]
# L1norm mean is: [2.56305076]
# L2norm mean is: [0.57504657]
# MSE_F mean is: [0.3472712]
# MSE_Y mean is: [0.49447944]
#
# R2= 0.6817692537068712
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.10304179891346653
# Average data variance is:  1.0
# Time taken to draw data :  0.03245997428894043
# run time is : 41.348578214645386
# RUN 98
# Runtime mean is: [32.31454372]
# Weighted accuracy mean is: [[0.80526316 0.87271751 0.85837809 0.69312567]]
# TPR mean is: [[0.92727273 0.87474747 0.77575758 0.4040404 ]]
# PPV mean is: [[0.13709738 0.31750621 0.48861632        nan]]
# MCC mean is: [[0.28358294 0.47227066 0.57010406 0.43124267]]
# L1norm mean is: [2.55466516]
# L2norm mean is: [0.57401743]
# MSE_F mean is: [0.34674429]
# MSE_Y mean is: [0.49338481]
#
# R2= 0.6669441903646217
# data generated
# Length-scales are:  [0.1118034 0.1118034 0.1118034 0.1118034 0.1118034]
# Noise variance is:  0.021412533221813218
# Average data variance is:  1.0
# Time taken to draw data :  0.03243565559387207
# run time is : 26.923272848129272
# RUN 99
# Runtime mean is: [32.26076068]
# Weighted accuracy mean is: [[0.80600744 0.87251462 0.85757576 0.69213184]]
# TPR mean is: [[0.926 0.874 0.776 0.404]]
# PPV mean is: [[0.13701673 0.31683114 0.49173015        nan]]
# MCC mean is: [[0.28317771 0.47155297 0.57229775 0.43315725]]
# L1norm mean is: [2.54618302]
# L2norm mean is: [0.57177659]
# MSE_F mean is: [0.34576179]
# MSE_Y mean is: [0.49366939]

# %%
namelist = ["Runtime", "MSE_F", "MSE_Y", "Acc", "Weighted_Acc", "TPR", "TNR", "PPV", "NPV", "AUC", "MCC"]
objlist = [Runtime, MSE_F, MSE_Y, Acc, Weighted_Acc, TPR, TNR, PPV, NPV, AUC, MCC]
#iters = np.random.choice(1000,100,False)
iters = np.linspace(0,99,100).astype(int)

for i in range(len(objlist)):
    print("Mean {0} is:".format(namelist[i]), np.mean(objlist[i][iters],0))

print("\n")
for i in range(len(objlist)):
    print("Median {0} is:".format(namelist[i]), np.median(objlist[i][iters],0))

print("\n")
quant = 0.25
for i in range(len(objlist)):
    if namelist[i] in ["Runtime", "MSE_F", "MSE_Y"]:
        print("{1} quantile {0} is:".format(namelist[i], quant), np.quantile(objlist[i][iters],1-quant,0))
    else:
        print("{1} quantile {0} is:".format(namelist[i], quant), np.quantile(objlist[i][iters],quant,0))
# Out:
# Mean Runtime is: [32.26076068]
# Mean MSE_F is: [0.34576179]
# Mean MSE_Y is: [0.49366939]
# Mean Acc is: [[0.6971 0.8705 0.9317 0.9516]]
# Mean Weighted_Acc is: [[0.80552632 0.87215789 0.85794737 0.69221053]]
# Mean TPR is: [[0.926 0.874 0.776 0.404]]
# Mean TNR is: [[0.68505263 0.87031579 0.93989474 0.98042105]]
# Mean PPV is: [[0.13701673 0.31683114 0.49173015        nan]]
# Mean NPV is: [[0.99440781 0.99239925 0.98775432 0.96921215]]
# Mean AUC is: [0.91734737]
# Mean MCC is: [[0.28317771 0.47155297 0.57229775 0.43315725]]
#
#
# Median Runtime is: [28.46202087]
# Median MSE_F is: [0.33300526]
# Median MSE_Y is: [0.47241939]
# Median Acc is: [[0.69 0.87 0.94 0.95]]
# Median Weighted_Acc is: [[0.82631579 0.87368421 0.87631579 0.69473684]]
# Median TPR is: [[1.  1.  0.8 0.4]]
# Median TNR is: [[0.68421053 0.88421053 0.94736842 0.98421053]]
# Median PPV is: [[0.13513514 0.26666667 0.44949495        nan]]
# Median NPV is: [[1.         1.         0.98907071 0.96907216]]
# Median AUC is: [0.94842105]
# Median MCC is: [[0.29304023 0.47368421 0.57894737 0.45814084]]
#
#
# 0.25 quantile Runtime is: [41.52716488]
# 0.25 quantile MSE_F is: [0.41701703]
# 0.25 quantile MSE_Y is: [0.55275422]
# 0.25 quantile Acc is: [[0.66   0.8275 0.91   0.94  ]]
# 0.25 quantile Weighted_Acc is: [[0.76578947 0.80526316 0.78815789 0.59473684]]
# 0.25 quantile TPR is: [[0.8 0.8 0.6 0.2]]
# 0.25 quantile TNR is: [[0.64210526 0.82894737 0.91578947 0.96842105]]
# 0.25 quantile PPV is: [[0.11627907 0.1758312  0.28571429        nan]]
# 0.25 quantile NPV is: [[0.98581343 0.98717949 0.97889138 0.95918367]]
# 0.25 quantile AUC is: [0.87052632]
# 0.25 quantile MCC is: [[0.24347975 0.32121258 0.40869069 0.29496309]]

# %%
from datetime import date
Output = {"Runtime" : Runtime, "Lambda" : Lambda, "L" : L, "L1norm" : L1norm, "L2norm" : L2norm, "MSE_F" : MSE_F
        , "MSE_Y" : MSE_Y, "Acc" : Acc, "Weighted_Acc" : Weighted_Acc, "TPR" :TPR, "TNR" : TNR, "PPV" : PPV, "NPV" : NPV, "AUC" : AUC, "MCC" : MCC}
String = "Stage1_MLII{13}_{0}_{1}_lsmean={12}_r2={14}_l0={2}_b2={3}_step={4}_MCpred={5}_n={6}_p={7}_q={8}_kern={9}_runs={10}_start={11}".format(
    "GP", date.today(), l_init, beta2, step[0], MC_pred[0],n,p,q,str(kern)[23:28], nruns, "random", lsmean, minibatch_size, r2)
np.save(String, Output) # saving
